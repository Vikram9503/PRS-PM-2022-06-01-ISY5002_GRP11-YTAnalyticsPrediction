# %%
#A package to use google drive
from google.colab import drive
drive.mount('/content/drive')
#'/gdrive/Shared drives/'
#https://stackoverflow.com/questions/54351852/accessing-shared-with-me-with-colab
# Out:
# Mounted at /content/drive

# %%
#Cloning a GitHub package youtube-bb to download and cutting videos into sub-videos across 23 classes
# !git clone https://github.com/mbuckler/youtube-bb.git /usr/local/lib/python3.7/dist-packages/youtube_bb
# Out:
# Cloning into '/usr/local/lib/python3.7/dist-packages/youtube_bb'...
# remote: Enumerating objects: 334, done.
# remote: Total 334 (delta 0), reused 0 (delta 0), pack-reused 334
# Receiving objects: 100% (334/334), 67.41 KiB | 5.62 MiB/s, done.
# Resolving deltas: 100% (190/190), done.

# %%
# !pip install ffmpy
# !pip install pillow
# !pip install futures
# !pip install youtube-dl
# Out:
# ...
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4712 sha256=1d5761a990dc97173583e8e748424a5072c4761ffe4972db1d190874fe952a25
#   Stored in directory: /root/.cache/pip/wheels/13/e4/6c/e8059816e86796a597c6e6b0d4c880630f51a1fcfa0befd5e6
# Successfully built ffmpy
# ...
# WARNING: Discarding https://files.pythonhosted.org/packages/55/db/97c1ca37edab586a1ae03d6892b6633d8eaa23b23ac40c7e5bbc55423c78/futures-3.0.5.tar.gz#sha256=0542525145d5afc984c88f914a0c85c77527f65946617edb5274f72406f981df (from https://pypi.org/simple/futures/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ...

# %%
#package to download and cut youtube videos
import imageio
import moviepy
import ffmpy
import futures
import youtube_dl
import PIL
import glob
import re
import os
import sys
import pprint
import shutil
pprint.pprint(sys.path)
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
#new_dir_path = '/content/drive/MyDrive/NUS/DSA5204 team work/002_imagefiles/YTBB/video_data'
#os.mkdir(new_dir_path)

# %%
#Downloading and video cutting into sub videos
# !python3 /usr/local/lib/python3.7/dist-packages/youtube_bb/download.py /content/gdrive/MyDrive/NUS/ISY5002_project_work/001_input_data/imagefiles/YTBB_videos 448
# Out:
# yt_bb_detection_train: Downloading annotations...
# --2022-03-06 15:27:15--  https://research.google.com/youtube-bb/yt_bb_detection_train.csv.gz
# Resolving research.google.com (research.google.com)... 108.177.127.101, 108.177.127.102, 108.177.127.100, ...
# Connecting to research.google.com (research.google.com)|108.177.127.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59724774 (57M) [application/gzip]
# Saving to: ‘yt_bb_detection_train.csv.gz’
#
# yt_bb_detection_tra 100%[===================>]  56.96M  20.8MB/s    in 2.7s
#
# 2022-03-06 15:27:18 (20.8 MB/s) - ‘yt_bb_detection_train.csv.gz’ saved [59724774/59724774]
#
# yt_bb_detection_train: Unzipping annotations...
# yt_bb_detection_train: Parsing annotations into clip data...
# yt_bb_detection_train: Sorting annotations...
